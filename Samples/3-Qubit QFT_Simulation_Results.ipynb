# %% [markdown]
# # Bit-Flip Error (Full Encode)

# %% [markdown]
# ## Device: ibm_perth

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 122, '001': 748, '010': 118, '011': 365, '100': 370, '101': 1938, '110': 130, '111': 209}
result_counts_EF = {'000': 142, '100': 145, '101': 77, '110': 274, '111': 140, '001': 101, '010': 500, '011': 364}

title = "ibm_perth"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibm_nairobi

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 184, '001': 801, '010': 61, '011': 310, '100': 539, '101': 1910, '110': 69, '111': 126}
result_counts_EF = {'000': 470, '100': 325, '101': 750, '110': 199, '111': 85, '001': 742, '010': 130, '011': 48}

title = "ibm_nairobi"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibm_oslo

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 87, '001': 627, '010': 24, '011': 165, '100': 89, '101': 2507, '110': 72, '111': 429}
result_counts_EF = {'000': 176, '100': 97, '101': 80, '110': 359, '111': 278, '001': 287, '010': 500, '011': 296}

title = "ibm_oslo"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_jakarta

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 80, '001': 293, '010': 107, '011': 409, '100': 268, '101': 2299, '110': 154, '111': 390}
result_counts_EF = {'000': 61, '100': 107, '101': 793, '110': 193, '111': 336, '001': 584, '010': 172, '011': 444}

title = "ibmq_jakarta"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_belem

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 141, '001': 454, '010': 78, '011': 208, '100': 343, '101': 2402, '110': 177, '111': 197}
result_counts_EF = {'000': 188, '100': 188, '101': 616, '110': 267, '111': 310, '001': 364, '010': 238, '011': 123}

title = "ibmq_belem"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_lima

# %%
from qiskit.visualization import plot_histogram

result_ideal = {'101': 1024}
result_counts = {'000': 179, '001': 748, '010': 73, '011': 302, '100': 278, '101': 1941, '110': 143, '111': 336}
result_counts_EF = {'000': 188, '100': 188, '101': 616, '110': 267, '111': 310, '001': 364, '010': 238, '011': 123}

{'000': 86, '100': 80, '101': 427, '110': 247, '111': 507, '001': 419, '010': 165, '011': 285}


title = "ibmq_lima"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_histogram([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# # Bit-Flip Error (Partial Encode)

# %% [markdown]
# ## Device: ibm_quito

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 64, '001': 294, '010': 57, '011': 176, '100': 373, '101': 2630, '110': 176, '111': 230}
result_counts_EF = {'000': 111, '001': 386, '100': 327, '101': 1992, '110': 150, '111': 65, '010': 91, '011': 50}

title = "ibm_quito"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_lima

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 180, '001': 319, '010': 82, '011': 160, '100': 574, '101': 2358, '110': 141, '111': 186}
result_counts_EF = {'000': 265, '001': 624, '100': 423, '101': 1358, '110': 254, '111': 72, '010': 143, '011': 34}

title = "ibmq_lima"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_belem

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 137, '001': 435, '010': 106, '011': 156, '100': 415, '101': 2421, '110': 147, '111': 183}
result_counts_EF = {'000': 271, '001': 574, '100': 399, '101': 1329, '110': 345, '111': 50, '010': 181, '011': 47}

title = "ibmq_belem"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibm_nairobi

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 141, '001': 393, '010': 31, '011': 139, '100': 231, '101': 2937, '110': 35, '111': 93}
result_counts_EF = {'000': 434, '001': 602, '100': 301, '101': 690, '110': 265, '111': 47, '010': 429, '011': 68}

title = "ibm_nairobi"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibm_perth

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 46, '001': 329, '010': 45, '011': 246, '100': 200, '101': 2858, '110': 93, '111': 183}
result_counts_EF = {'000': 88, '001': 531, '100': 337, '101': 1832, '110': 167, '111': 61, '010': 101, '011': 86}

title = "ibm_perth"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibm_lagos

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 37, '001': 212, '010': 23, '011': 297, '100': 62, '101': 2945, '110': 71, '111': 353}
result_counts_EF = {'000': 472, '001': 934, '100': 393, '101': 546, '110': 419, '111': 124, '010': 301, '011': 71}

title = "ibm_lagos"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)

# %% [markdown]
# ## Device: ibmq_jakarta

# %%
from qiskit.visualization import plot_distribution

result_ideal = {'101': 1024}
result_counts = {'000': 66, '001': 335, '010': 44, '011': 164, '100': 328, '101': 2825, '110': 53, '111': 185}
result_counts_EF = {'000': 249, '001': 557, '100': 278, '101': 1327, '110': 419, '111': 73, '010': 136, '011': 39}

title = "ibmq_jakarta"
legend = ["Ideal", "Without Error Filtering", "With Error Filtering"]
plot_distribution([result_ideal, result_counts, result_counts_EF], legend=legend, bar_labels=False, title=title)
