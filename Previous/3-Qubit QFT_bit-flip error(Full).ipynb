# %%
import matplotlib.pyplot as plt
import numpy as np
from qiskit import QuantumCircuit, Aer, transpile, assemble
from qiskit.visualization import plot_histogram
from math import gcd
from numpy.random import randint
from numpy import pi

# %%
from qiskit import IBMQ

provider = IBMQ.load_account()
my_provider = IBMQ.get_provider(hub='ibm-q', group='open', project='main')
backends = my_provider.backends()

for backend in backends:
    print(backend) # only available for 7-qubit device
# Out:
# ibmqfactory.load_account:WARNING:2023-04-11 14:17:52,619: Credentials are already in use. The existing account in the session will be replaced.
# ibmq_qasm_simulator
# ibmq_lima
# ibmq_belem
# ibmq_quito
# simulator_statevector
# simulator_mps
# simulator_extended_stabilizer
# simulator_stabilizer
# ibmq_jakarta
# ibmq_manila
# ibm_lagos
# ibm_nairobi
# ibm_perth
# ibm_oslo

# %%
def qft_rotations(circuit, n):
    """Performs qft on the first n qubits in circuit (without swaps)"""
    if n == 0:
        return circuit
    n -= 1
    circuit.h(n)
    for qubit in range(n):
        circuit.cp(pi/2**(n-qubit), qubit, n)
    # At the end of our function, we call the same function again on
    # the next qubits (we reduced n by one earlier in the function)
    qft_rotations(circuit, n)

# %%
def swap_registers(circuit, n):
    for qubit in range(n//2):
        circuit.swap(qubit, n-qubit-1)
    return circuit

# %%
def qft(circuit, n):
    """QFT on the first n qubits in circuit"""
    qft_rotations(circuit, n)
    swap_registers(circuit, n)
    return circuit

# %%
qc = QuantumCircuit(3, 3)

qc.x(1)

qc.barrier()
qft(qc,3)
qc.barrier()
qc.measure(range(3), range(3))
qc.draw()
# Out:
#            ░                                      ┌───┐    ░ ┌─┐
# q_0: ──────░───────■──────────────────────■───────┤ H ├─X──░─┤M├──────
#      ┌───┐ ░       │                ┌───┐ │P(π/2) └───┘ │  ░ └╥┘┌─┐
# q_1: ┤ X ├─░───────┼────────■───────┤ H ├─■─────────────┼──░──╫─┤M├───
#      └───┘ ░ ┌───┐ │P(π/4)  │P(π/2) └───┘               │  ░  ║ └╥┘┌─┐
# q_2: ──────░─┤ H ├─■────────■───────────────────────────X──░──╫──╫─┤M├
#            ░ └───┘                                         ░  ║  ║ └╥┘
# c: 3/═════════════════════════════════════════════════════════╩══╩══╩═
#                                                               0  1  2

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_transpiled = transpile(qc, aer_sim, optimization_level=0)
qobj = assemble(qc_transpiled)

results = aer_sim.run(qobj).result()
counts = results.get_counts()
plot_histogram(counts)

# %%
def inverse_qft(circuit, n):
    """Does the inverse QFT on the first n qubits in circuit"""
    # First we create a QFT circuit of the correct size:
    qft_circ = qft(QuantumCircuit(n), n)
    # Then we take the inverse of this circuit
    invqft_circ = qft_circ.inverse()
    # And add it to the first n qubits in our existing circuit
    circuit.append(invqft_circ, circuit.qubits[:n])
    return circuit.decompose() # .decompose() allows us to see the individual gates

# %%
nqubits = 3
number = 5
qc = QuantumCircuit(nqubits)
for qubit in range(nqubits):
    qc.h(qubit)
qc.p(number*pi/4,0)
qc.p(number*pi/2,1)
qc.p(number*pi,2)

qc.draw()
# Out:
#      ┌───┐┌─────────┐
# q_0: ┤ H ├┤ P(5π/4) ├
#      ├───┤├─────────┤
# q_1: ┤ H ├┤ P(5π/2) ├
#      ├───┤└┬───────┬┘
# q_2: ┤ H ├─┤ P(5π) ├─
#      └───┘ └───────┘

# %%
qc = inverse_qft(qc, nqubits)
qc.measure_all()
qc.draw()
# Out:
#         ┌─────────┐┌─────────────┐   ┌───┐                                   »
#    q_0: ┤ U2(0,π) ├┤ U(0,0,5π/4) ├─X─┤ H ├─■────────────────────────■────────»
#         ├─────────┤├─────────────┤ │ └───┘ │P(-π/2) ┌───┐           │        »
#    q_1: ┤ U2(0,π) ├┤ U(0,0,5π/2) ├─┼───────■────────┤ H ├─■─────────┼────────»
#         ├─────────┤└┬───────────┬┘ │                └───┘ │P(-π/2)  │P(-π/4) »
#    q_2: ┤ U2(0,π) ├─┤ U(0,0,5π) ├──X──────────────────────■─────────■────────»
#         └─────────┘ └───────────┘                                            »
# meas: 3/═════════════════════════════════════════════════════════════════════»
#                                                                              »
# «              ░ ┌─┐
# «   q_0: ──────░─┤M├──────
# «              ░ └╥┘┌─┐
# «   q_1: ──────░──╫─┤M├───
# «        ┌───┐ ░  ║ └╥┘┌─┐
# «   q_2: ┤ H ├─░──╫──╫─┤M├
# «        └───┘ ░  ║  ║ └╥┘
# «meas: 3/═════════╩══╩══╩═
# «                 0  1  2

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_transpiled = transpile(qc, aer_sim, optimization_level=0)
qobj = assemble(qc_transpiled)

results = aer_sim.run(qobj).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'101': 1024}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_perth')
qc_perth = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,5])

print("Circuit Depth :", qc_perth.depth())
results = backend.run(qc_perth).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 32
# {'000': 122, '001': 748, '010': 118, '011': 365, '100': 370, '101': 1938, '110': 130, '111': 209}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_nairobi')
qc_nairobi = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,5])

print("Circuit Depth :", qc_nairobi.depth())
results = backend.run(qc_nairobi).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 32
# {'000': 184, '001': 801, '010': 61, '011': 310, '100': 539, '101': 1910, '110': 69, '111': 126}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_oslo')
qc_oslo = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,5])

print("Circuit Depth :", qc_oslo.depth())
results = backend.run(qc_oslo).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 29
# {'000': 87, '001': 627, '010': 24, '011': 165, '100': 89, '101': 2507, '110': 72, '111': 429}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_jakarta')
qc_jakarta = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,5])

print("Circuit Depth :", qc_jakarta.depth())
results = backend.run(qc_jakarta).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 33
# {'000': 80, '001': 293, '010': 107, '011': 409, '100': 268, '101': 2299, '110': 154, '111': 390}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_manila')
qc_manila = transpile(qc, backend, optimization_level=2, initial_layout=[2,3,4])

print("Circuit Depth :", qc_manila.depth())
results = backend.run(qc_manila).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 32
# {'000': 83, '001': 457, '010': 37, '011': 63, '100': 179, '101': 2794, '110': 158, '111': 229}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_quito')
qc_quito = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4])

print("Circuit Depth :", qc_quito.depth())
results = backend.run(qc_quito).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 29
# {'000': 78, '001': 264, '010': 48, '011': 361, '100': 337, '101': 2444, '110': 101, '111': 367}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_belem')
qc_belem = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4])

print("Circuit Depth :", qc_belem.depth())
results = backend.run(qc_belem).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 32
# {'000': 141, '001': 454, '010': 78, '011': 208, '100': 343, '101': 2402, '110': 177, '111': 197}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_lima')
qc_lima = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4])

print("Circuit Depth :", qc_lima.depth())
results = backend.run(qc_lima).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 33
# {'000': 179, '001': 748, '010': 73, '011': 302, '100': 278, '101': 1941, '110': 143, '111': 336}

# %%
number = 5
qc = QuantumCircuit(5)
qc.h([0,3,4])
qc.p(number*pi/4,0)
qc.p(number*pi/2,3)
qc.p(number*pi,4)

qc.draw()
# Out:
#      ┌───┐┌─────────┐
# q_0: ┤ H ├┤ P(5π/4) ├
#      └───┘└─────────┘
# q_1: ────────────────
#
# q_2: ────────────────
#      ┌───┐┌─────────┐
# q_3: ┤ H ├┤ P(5π/2) ├
#      ├───┤└┬───────┬┘
# q_4: ┤ H ├─┤ P(5π) ├─
#      └───┘ └───────┘

# %%
# Encode
qc.cx(0,1)

# CCX_L
qc.ccx(0,1,4)

# CXX_L
qc.cx(4,0)
qc.cx(4,1)

# CCX_L
qc.ccx(0,1,4)

# H_L
qc.h(1)
qc.cry(pi,1,0)
qc.h([0,1])

# CP_L
qc.mcp(-pi/2, [0,1], 3)
qc.h(3)

# CP_L
qc.mcp(-pi/4, [0,1], 4)
qc.cp(-pi/2,3,4)
qc.h(4)

# EF
qc.cx(0,2)
qc.cx(1,2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐┌─────────┐          ┌───┐               ┌───────┐┌───┐          »
#    q_0: ┤ H ├┤ P(5π/4) ├──■────■──┤ X ├───────■───────┤ Ry(π) ├┤ H ├─■────────»
#         └───┘└─────────┘┌─┴─┐  │  └─┬─┘┌───┐  │  ┌───┐└───┬───┘├───┤ │        »
#    q_1: ────────────────┤ X ├──■────┼──┤ X ├──■──┤ H ├────■────┤ H ├─■────────»
#                         └───┘  │    │  └─┬─┘  │  └───┘         └───┘ │        »
#    q_2: ───────────────────────┼────┼────┼────┼──────────────────────┼────────»
#         ┌───┐┌─────────┐       │    │    │    │                      │P(-π/2) »
#    q_3: ┤ H ├┤ P(5π/2) ├───────┼────┼────┼────┼──────────────────────■────────»
#         ├───┤└┬───────┬┘     ┌─┴─┐  │    │  ┌─┴─┐                             »
#    q_4: ┤ H ├─┤ P(5π) ├──────┤ X ├──■────■──┤ X ├─────────────────────────────»
#         └───┘ └───────┘      └───┘          └───┘                             »
# meas: 5/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «                                       ░ ┌─┐
# «   q_0: ──────■────────────■───────────░─┤M├────────────
# «              │            │           ░ └╥┘┌─┐
# «   q_1: ──────■────────────┼───────■───░──╫─┤M├─────────
# «              │          ┌─┴─┐   ┌─┴─┐ ░  ║ └╥┘┌─┐
# «   q_2: ──────┼──────────┤ X ├───┤ X ├─░──╫──╫─┤M├──────
# «        ┌───┐ │          └───┘   └───┘ ░  ║  ║ └╥┘┌─┐
# «   q_3: ┤ H ├─┼─────────■──────────────░──╫──╫──╫─┤M├───
# «        └───┘ │P(-π/4)  │P(-π/2) ┌───┐ ░  ║  ║  ║ └╥┘┌─┐
# «   q_4: ──────■─────────■────────┤ H ├─░──╫──╫──╫──╫─┤M├
# «                                 └───┘ ░  ║  ║  ║  ║ └╥┘
# «meas: 5/══════════════════════════════════╩══╩══╩══╩══╩═
# «                                          0  1  2  3  4

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_transpiled = transpile(qc, aer_sim, optimization_level=0)
qobj = assemble(qc_transpiled)

results = aer_sim.run(qobj).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'10011': 1024}

# %%
number = 5
qc = QuantumCircuit(5)
qc.h([0,3,4])
qc.p(number*pi/4,0)
qc.p(number*pi/2,3)
qc.p(number*pi,4)

qc.draw()
# Out:
#      ┌───┐┌─────────┐
# q_0: ┤ H ├┤ P(5π/4) ├
#      └───┘└─────────┘
# q_1: ────────────────
#
# q_2: ────────────────
#      ┌───┐┌─────────┐
# q_3: ┤ H ├┤ P(5π/2) ├
#      ├───┤└┬───────┬┘
# q_4: ┤ H ├─┤ P(5π) ├─
#      └───┘ └───────┘

# %%
# Encode
qc.cx(0,1)

# CCX_L
qc.csx(0,4)
qc.cx(1,0)
qc.csx(0,4)
qc.cx(1,0)
qc.csx(0,4)

# CXX_L
qc.cx(0,1)
qc.cx(4,0)
qc.cx(0,1)

# CCX_L
qc.csx(0,4)
qc.cx(1,0)
qc.csx(0,4)
qc.cx(1,0)
qc.csx(0,4)

# H_L
qc.h(1)
qc.cry(pi,1,0)
qc.h([0,1])

# CP_L
qc.cp(-pi/4,0,3)
qc.cx(1,0)
qc.cp(-pi/4,0,3)
qc.cx(1,0)
qc.cp(-pi/4,0,3)
qc.h(3)

# CP_L
qc.cp(-pi/8,0,4)
qc.cx(1,0)
qc.cp(-pi/8,0,4)
qc.cx(1,0)
qc.cp(-pi/8,0,4)
qc.cp(-pi/2,3,4)
qc.h(4)

# EF
qc.cx(0,2)
qc.cx(1,2)

qc.measure_all()
qc.draw()
# Out:
#         ┌───┐┌─────────┐           ┌───┐      ┌───┐           ┌───┐           »
#    q_0: ┤ H ├┤ P(5π/4) ├──■────■───┤ X ├──■───┤ X ├──■─────■──┤ X ├──■────■───»
#         └───┘└─────────┘┌─┴─┐  │   └─┬─┘  │   └─┬─┘  │   ┌─┴─┐└─┬─┘┌─┴─┐  │   »
#    q_1: ────────────────┤ X ├──┼─────■────┼─────■────┼───┤ X ├──┼──┤ X ├──┼───»
#                         └───┘  │          │          │   └───┘  │  └───┘  │   »
#    q_2: ───────────────────────┼──────────┼──────────┼──────────┼─────────┼───»
#         ┌───┐┌─────────┐       │          │          │          │         │   »
#    q_3: ┤ H ├┤ P(5π/2) ├───────┼──────────┼──────────┼──────────┼─────────┼───»
#         ├───┤└┬───────┬┘     ┌─┴──┐     ┌─┴──┐     ┌─┴──┐       │       ┌─┴──┐»
#    q_4: ┤ H ├─┤ P(5π) ├──────┤ Sx ├─────┤ Sx ├─────┤ Sx ├───────■───────┤ Sx ├»
#         └───┘ └───────┘      └────┘     └────┘     └────┘               └────┘»
# meas: 5/══════════════════════════════════════════════════════════════════════»
#                                                                               »
# «        ┌───┐      ┌───┐           ┌───────┐┌───┐          ┌───┐          »
# «   q_0: ┤ X ├──■───┤ X ├──■────────┤ Ry(π) ├┤ H ├─■────────┤ X ├─■────────»
# «        └─┬─┘  │   └─┬─┘  │   ┌───┐└───┬───┘├───┤ │        └─┬─┘ │        »
# «   q_1: ──■────┼─────■────┼───┤ H ├────■────┤ H ├─┼──────────■───┼────────»
# «               │          │   └───┘         └───┘ │              │        »
# «   q_2: ───────┼──────────┼───────────────────────┼──────────────┼────────»
# «               │          │                       │P(-π/4)       │P(-π/4) »
# «   q_3: ───────┼──────────┼───────────────────────■──────────────■────────»
# «             ┌─┴──┐     ┌─┴──┐                                            »
# «   q_4: ─────┤ Sx ├─────┤ Sx ├────────────────────────────────────────────»
# «             └────┘     └────┘                                            »
# «meas: 5/══════════════════════════════════════════════════════════════════»
# «                                                                          »
# «        ┌───┐                         ┌───┐          ┌───┐                    »
# «   q_0: ┤ X ├─■──────────────■────────┤ X ├─■────────┤ X ├─■────────────■─────»
# «        └─┬─┘ │              │        └─┬─┘ │        └─┬─┘ │            │     »
# «   q_1: ──■───┼──────────────┼──────────■───┼──────────■───┼────────────┼─────»
# «              │              │              │              │          ┌─┴─┐   »
# «   q_2: ──────┼──────────────┼──────────────┼──────────────┼──────────┤ X ├───»
# «              │P(-π/4) ┌───┐ │              │              │          └───┘   »
# «   q_3: ──────■────────┤ H ├─┼──────────────┼──────────────┼─────────■────────»
# «                       └───┘ │P(-π/8)       │P(-π/8)       │P(-π/8)  │P(-π/2) »
# «   q_4: ─────────────────────■──────────────■──────────────■─────────■────────»
# «                                                                              »
# «meas: 5/══════════════════════════════════════════════════════════════════════»
# «                                                                              »
# «              ░ ┌─┐
# «   q_0: ──────░─┤M├────────────
# «              ░ └╥┘┌─┐
# «   q_1: ──■───░──╫─┤M├─────────
# «        ┌─┴─┐ ░  ║ └╥┘┌─┐
# «   q_2: ┤ X ├─░──╫──╫─┤M├──────
# «        └───┘ ░  ║  ║ └╥┘┌─┐
# «   q_3: ──────░──╫──╫──╫─┤M├───
# «        ┌───┐ ░  ║  ║  ║ └╥┘┌─┐
# «   q_4: ┤ H ├─░──╫──╫──╫──╫─┤M├
# «        └───┘ ░  ║  ║  ║  ║ └╥┘
# «meas: 5/═════════╩══╩══╩══╩══╩═
# «                 0  1  2  3  4

# %%
aer_sim = Aer.get_backend('aer_simulator')
qc_transpiled = transpile(qc, aer_sim, optimization_level=0)
qobj = assemble(qc_transpiled)

results = aer_sim.run(qobj).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# {'10011': 1024}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_perth')
qc_perth = transpile(qc, backend, optimization_level=2, initial_layout=[5,3,1,4,6])

print("Circuit Depth :", qc_perth.depth())
results = backend.run(qc_perth).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 86
# {'00000': 142, '00001': 59, '10000': 145, '10001': 26, '10010': 26, '10011': 77, '10100': 85, '10101': 23, '10110': 26, '10111': 109, '11000': 274, '11001': 69, '11010': 51, '11011': 140, '11100': 157, '11101': 57, '11110': 82, '11111': 177, '00010': 34, '00011': 101, '00100': 86, '00101': 31, '00110': 31, '00111': 109, '01000': 500, '01001': 158, '01010': 119, '01011': 364, '01100': 202, '01101': 86, '01110': 121, '01111': 333}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_nairobi')
qc_nairobi = transpile(qc, backend, optimization_level=2, initial_layout=[5,3,1,4,6])

print("Circuit Depth :", qc_nairobi.depth())
results = backend.run(qc_nairobi).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 86
# {'00000': 470, '00001': 47, '10000': 325, '10001': 49, '10010': 60, '10011': 750, '10100': 31, '10101': 234, '10110': 110, '10111': 43, '11000': 199, '11001': 17, '11010': 16, '11011': 85, '11100': 13, '11101': 62, '11110': 37, '11111': 6, '00010': 62, '00011': 742, '00100': 23, '00101': 143, '00110': 124, '00111': 38, '01000': 130, '01001': 22, '01010': 10, '01011': 48, '01100': 11, '01101': 51, '01110': 32, '01111': 10}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibm_oslo')
qc_oslo = transpile(qc, backend, optimization_level=2, initial_layout=[5,3,1,4,6])

print("Circuit Depth :", qc_oslo.depth())
results = backend.run(qc_oslo).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 86
# {'00000': 176, '00001': 16, '10000': 97, '10001': 5, '10010': 4, '10011': 80, '10100': 5, '10101': 53, '10110': 71, '10111': 11, '11000': 359, '11001': 16, '11010': 30, '11011': 278, '11100': 18, '11101': 230, '11110': 269, '11111': 42, '00010': 13, '00011': 287, '00100': 10, '00101': 177, '00110': 155, '00111': 19, '01000': 500, '01001': 22, '01010': 24, '01011': 296, '01100': 21, '01101': 288, '01110': 387, '01111': 41}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_jakarta')
qc_jakarta = transpile(qc, backend, optimization_level=2, initial_layout=[5,3,1,4,6])

print("Circuit Depth :", qc_jakarta.depth())
results = backend.run(qc_jakarta).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 88
# {'00000': 61, '00001': 52, '10000': 107, '10001': 75, '10010': 42, '10011': 793, '10100': 9, '10101': 178, '10110': 83, '10111': 33, '11000': 193, '11001': 35, '11010': 27, '11011': 336, '11100': 16, '11101': 58, '11110': 73, '11111': 22, '00010': 48, '00011': 584, '00100': 23, '00101': 125, '00110': 83, '00111': 29, '01000': 172, '01001': 33, '01010': 41, '01011': 444, '01100': 19, '01101': 70, '01110': 92, '01111': 44}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_manila')
qc_manila = transpile(qc, backend, optimization_level=2, initial_layout=[2,3,4])

print("Circuit Depth :", qc_manila.depth())
results = backend.run(qc_manila).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# ---------------------------------------------------------------------------
# LayoutError                               Traceback (most recent call last)
# <ipython-input-129-25c05d7817d0> in <module>
#       2
#       3 backend = my_provider.get_backend('ibmq_manila')
# ----> 4 qc_manila = transpile(qc, backend, optimization_level=2, initial_layout=[2,3,4])
#       5
#       6 print("Circuit Depth :", qc_manila.depth())
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in transpile(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, timing_constraints, seed_transpiler, optimization_level, callback, output_name, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     274
#     275     # Get transpile_args to configure the circuit transpilation job(s)
# --> 276     transpile_args = _parse_transpile_args(
#     277         circuits,
#     278         backend,
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _parse_transpile_args(circuits, backend, basis_gates, inst_map, coupling_map, backend_properties, initial_layout, layout_method, routing_method, translation_method, scheduling_method, instruction_durations, dt, approximation_degree, seed_transpiler, optimization_level, callback, output_name, timing_constraints, unitary_synthesis_method, unitary_synthesis_plugin_config, target)
#     525     backend_properties = _parse_backend_properties(backend_properties, backend, num_circuits)
#     526     backend_num_qubits = _parse_backend_num_qubits(backend, num_circuits)
# --> 527     initial_layout = _parse_initial_layout(initial_layout, circuits)
#     528     layout_method = _parse_layout_method(layout_method, num_circuits)
#     529     routing_method = _parse_routing_method(routing_method, num_circuits)
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _parse_initial_layout(initial_layout, circuits)
#     900     else:
#     901         # even if one layout, but multiple circuits, the layout needs to be adapted for each
# --> 902         initial_layout = [_layout_from_raw(initial_layout, circ) for circ in circuits]
#     903
#     904     if not isinstance(initial_layout, list):
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in <listcomp>(.0)
#     900     else:
#     901         # even if one layout, but multiple circuits, the layout needs to be adapted for each
# --> 902         initial_layout = [_layout_from_raw(initial_layout, circ) for circ in circuits]
#     903
#     904     if not isinstance(initial_layout, list):
#
# ~\anaconda3\lib\site-packages\qiskit\compiler\transpiler.py in _layout_from_raw(initial_layout, circuit)
#     881         elif isinstancelist(initial_layout):
#     882             if all(isinstanceint(elem) for elem in initial_layout):
# --> 883                 initial_layout = Layout.from_intlist(initial_layout, *circuit.qregs)
#     884             elif all(elem is None or isinstance(elem, Qubit) for elem in initial_layout):
#     885                 initial_layout = Layout.from_qubit_list(initial_layout, *circuit.qregs)
#
# ~\anaconda3\lib\site-packages\qiskit\transpiler\layout.py in from_intlist(int_list, *qregs)
#     311         # Check if list is too short to cover all qubits
#     312         if len(int_list) != num_qubits:
# --> 313             raise LayoutError(
#     314                 f"Integer list length ({len(int_list)}) must equal number of qubits "
#     315                 f"in circuit ({num_qubits}): {int_list}."
#
# LayoutError: 'Integer list length (3) must equal number of qubits in circuit (5): [2, 3, 4].'

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_quito')
qc_quito = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4,2,0])

print("Circuit Depth :", qc_quito.depth())
results = backend.run(qc_quito).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 84
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\api\session.py in request(self, method, url, bare, **kwargs)
#     277             response = super().request(method, final_url, headers=headers, **kwargs)
# --> 278             response.raise_for_status()
#     279         except RequestException as ex:
#
# ~\anaconda3\lib\site-packages\requests\models.py in raise_for_status(self)
#     959         if http_error_msg:
# --> 960             raise HTTPError(http_error_msg, response=self)
#     961
#
# HTTPError: 401 Client Error: Unauthorized for url: https://api-qcon.quantum-computing.ibm.com/api/Network/ibm-q/Groups/open/Projects/main/Jobs
#
# The above exception was the direct cause of the following exception:
#
# RequestsApiError                          Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\ibmqbackend.py in _submit_job(self, qobj, job_name, job_tags, experiment_id, live_data_enabled)
#     380             qobj_dict = qobj.to_dict()
# --> 381             submit_info = self._api_client.job_submit(
#     382                 backend_name=self.name(),
#
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\api\clients\account.py in job_submit(self, backend_name, qobj_dict, job_name, job_tags, experiment_id, live_data_enabled)
#     226         # Create a remote job instance on the server.
# --> 227         job_info = self.account_api.create_remote_job(
#     228             backend_name,
#
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\api\rest\account.py in create_remote_job(self, backend_name, job_name, job_tags, experiment_id, live_data_enabled)
#     208
# --> 209         return self.session.post(url, json=payload).json()
#     210
#
# ~\anaconda3\lib\site-packages\requests\sessions.py in post(self, url, data, json, **kwargs)
#     576
# --> 577         return self.request('POST', url, data=data, json=json, **kwargs)
#     578
#
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\api\session.py in request(self, method, url, bare, **kwargs)
#     299
# --> 300             raise RequestsApiError(message, status_code) from ex
#     301
#
# RequestsApiError: '401 Client Error: Unauthorized for url: https://api-qcon.quantum-computing.ibm.com/api/Network/ibm-q/Groups/open/Projects/main/Jobs. Invalid Access Token, Error code: 2407.'
#
# The above exception was the direct cause of the following exception:
#
# IBMQBackendApiError                       Traceback (most recent call last)
# <ipython-input-130-9b34d5bd09a7> in <module>
#       5
#       6 print("Circuit Depth :", qc_quito.depth())
# ----> 7 results = backend.run(qc_quito).result()
#       8 counts = results.get_counts()
#       9 print(counts)
#
# ~\anaconda3\lib\site-packages\qiskit\utils\deprecation.py in wrapper(*args, **kwargs)
#      25             if kwargs:
#      26                 _rename_kwargs(func.__name__, kwargs, kwarg_map)
# ---> 27             return func(*args, **kwargs)
#      28
#      29         return wrapper
#
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\ibmqbackend.py in run(self, circuits, job_name, job_share_level, job_tags, experiment_id, header, shots, memory, qubit_lo_freq, meas_lo_freq, schedule_los, meas_level, meas_return, memory_slots, memory_slot_size, rep_time, rep_delay, init_qubits, parameter_binds, use_measure_esp, live_data_enabled, **run_config)
#     328             qobj = assemble(circuits, self, **run_config_dict)
#     329
# --> 330         return self._submit_job(qobj, job_name, job_tags, experiment_id, live_data_enabled)
#     331
#     332     def _get_run_config(self, **kwargs: Any) -> Dict:
#
# ~\anaconda3\lib\site-packages\qiskit\providers\ibmq\ibmqbackend.py in _submit_job(self, qobj, job_name, job_tags, experiment_id, live_data_enabled)
#     389             if 'Error code: 3458' in str(ex):
#     390                 raise IBMQBackendJobLimitError('Error submitting job: {}'.format(str(ex))) from ex
# --> 391             raise IBMQBackendApiError('Error submitting job: {}'.format(str(ex))) from ex
#     392
#     393         # Error in the job after submission:
#
# IBMQBackendApiError: "Error submitting job: '401 Client Error: Unauthorized for url: https://api-qcon.quantum-computing.ibm.com/api/Network/ibm-q/Groups/open/Projects/main/Jobs. Invalid Access Token, Error code: 2407.'"

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_belem')
qc_belem = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4,2,0])

print("Circuit Depth :", qc_belem.depth())
results = backend.run(qc_belem).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 84
# {'00000': 188, '00001': 40, '10000': 188, '10001': 50, '10010': 52, '10011': 616, '10100': 21, '10101': 251, '10110': 153, '10111': 42, '11000': 267, '11001': 22, '11010': 41, '11011': 310, '11100': 20, '11101': 87, '11110': 128, '11111': 35, '00010': 53, '00011': 364, '00100': 27, '00101': 213, '00110': 135, '00111': 31, '01000': 238, '01001': 13, '01010': 35, '01011': 123, '01100': 24, '01101': 92, '01110': 119, '01111': 22}

# %%
from qiskit import IBMQ

backend = my_provider.get_backend('ibmq_lima')
qc_lima = transpile(qc, backend, optimization_level=2, initial_layout=[1,3,4,2,0])

print("Circuit Depth :", qc_lima.depth())
results = backend.run(qc_lima).result()
counts = results.get_counts()
print(counts)
plot_histogram(counts)
# Out:
# Circuit Depth : 88
# {'00000': 86, '00001': 29, '10000': 80, '10001': 16, '10010': 91, '10011': 427, '10100': 38, '10101': 154, '10110': 120, '10111': 48, '11000': 247, '11001': 26, '11010': 105, '11011': 507, '11100': 28, '11101': 102, '11110': 139, '11111': 43, '00010': 80, '00011': 419, '00100': 56, '00101': 147, '00110': 122, '00111': 36, '01000': 165, '01001': 14, '01010': 62, '01011': 285, '01100': 47, '01101': 99, '01110': 136, '01111': 46}
